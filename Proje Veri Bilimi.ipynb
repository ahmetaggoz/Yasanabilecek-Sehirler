# %% [markdown]
# > # Ülkeler ve Yaşam Maliyetleri
#
# ![Yaşam](https://cdn2.psychologytoday.com/assets/styles/manual_crop_1_91_1_1528x800/public/field_blog_entry_teaser_image/2020-10/purposeoflife.jpg?itok=G_3RzDjy)

# %%
import pandas as pd

df = pd.read_csv('cost-of-living.csv')

# %%
df.rename(columns ={'city':'Şehir'},inplace=True)
df.rename(columns ={'country':'Ülke'},inplace=True)
df.rename(columns ={'data_quality':'Veri Kalitesi'},inplace=True)

# %% [markdown]
# > Aşağıda x1,x2,x3... olarak tanımlanan sütun adları ve açıklamaları yer almaktadır.
# Sütun adları tablonun şekline zarar vereceğinden kısaltmaları olduğu gibi (x1,x2,x3, vs.) bıraktım. Aşağıdaki tabloda her şehirdeki temel gıda malzemeleri, binek otomobil fiyatları, merkez/merkez dışı ev kiralama ve m2 başına satın alma fiyatları, okul öncesi eğitim 1 yıllık ücretleri, ilkokul 1 yıllık eğitim ücretleri şeklinde açıklamalarla her x sütununun karşılık geldiği anlam açıklanıyor.

# %%
df2 = pd.read_excel('açıklama.xlsx')

df2
# Out:
#             Sütun                                           Açıklama
# 0           Şehir                                        Şehrin ismi
# 1            Ülke                                       Ülkenin ismi
# 2              x1                         Yemek, Ucuz Restoran (USD)
# 3              x2  2 Kişilik Yemek, Orta Sınıf Restoran, Üç Çeşit...
# 4              x3  McDonalds'ta McMeal (veya Eşdeğer Birleşik Yem...
# 5              x4   Yerli Bira (0,5 litre fıçı, restoranlarda) (USD)
# 6              x5  İthal Bira (0,33 litrelik şişe, restoranlarda)...
# 7              x6             Kapuçino (normal, restoranlarda) (USD)
# 8              x7  Kola/Pepsi (0,33 litrelik şişe, restoranlarda)...
# 9              x8       Su (0,33 litrelik şişe, restoranlarda) (USD)
# 10             x9                      Süt (normal), (1 litre) (USD)
# 11            x10                      Taze Beyaz Ekmek (500g) (USD)
# 12            x11                        Pirinç (beyaz), (1kg) (USD)
# ...

# %%
df
# Out:
#       Unnamed: 0               Şehir         Ülke     x1     x2     x3     x4  \
# 0              0               Delhi        India   4.90  22.04   4.28   1.84
# 1              1            Shanghai        China   5.59  40.51   5.59   1.12
# 2              2             Jakarta    Indonesia   2.54  22.25   3.50   2.02
# 3              3              Manila  Philippines   3.54  27.40   3.54   1.24
# 4              4               Seoul  South Korea   7.16  52.77   6.03   3.02
# ...          ...                 ...          ...    ...    ...    ...    ...
# 4869        4869        Peterborough    Australia    NaN    NaN    NaN    NaN
# 4870        4870          Georgetown    Australia    NaN    NaN    NaN    NaN
# 4871        4871  Ixtapa Zihuatanejo       Mexico   5.19  31.13  12.97   0.99
# 4872        4872             Iqaluit       Canada  29.78  74.61  13.77   6.70
# 4873        4873              Neiafu        Tonga    NaN  29.53  10.55  10.55
#
# ...

# %% [markdown]
# # Ülkeler ve Hava Kirliliği
#
# ![Hava kirliliği](https://cdn.evrimagaci.org/C2j88iDMHk1jP9i17wXaypK_iGM=/evrimagaci.org%2Fpublic%2Fcontent_media%2Ff9526a47ec64220880d54632b251a303.jpg)

# %%
df3 = pd.read_csv('global air pollution dataset.csv')
df3
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %% [markdown]
# > # Ülkeler ve Ekonomik Aktörler
#
# ![Finansal özgürlükler](https://d1ngglk168riv7.cloudfront.net/n/wp-content/uploads/2021/05/18111354/Cover-Image.jpg)

# %%
df4 = pd.read_csv('economic freedom index.csv')
df4
# Out:
#      ÜlkeID    Ülke İsmi      WEBNAME                         Bölge  \
# 0         1  Afghanistan  Afghanistan                  Asia-Pacific
# 1         2      Albania      Albania                        Europe
# 2         3      Algeria      Algeria  Middle East and North Africa
# 3         4       Angola       Angola            Sub-Saharan Africa
# 4         5    Argentina    Argentina                      Americas
# ..      ...          ...          ...                           ...
# 181     179    Venezuela    Venezuela                      Americas
# 182     180      Vietnam      Vietnam                  Asia-Pacific
# 183     181        Yemen        Yemen  Middle East and North Africa
# 184     182       Zambia       Zambia            Sub-Saharan Africa
# 185     183     Zimbabwe     Zimbabwe            Sub-Saharan Africa
#
#      Dünya Sıralaması  Bölge Sıralaması  2019 Skoru  Mülkiyet hakları  \
# 0               152.0              39.0        51.5              19.6
# ...

# %% [markdown]
# > # Ülkeler ve Protestolar
#
#
# ![Protesto oranları](https://i.hizliresim.com/ls5mnba.jpg)

# %%
df5 = pd.read_csv('GlobalProtestTracker-.csv')

df5
# Out:
#           Ülke                       Protesto Adı Başlama Tarihi  \
# 0    Argentina       Agricultural policy protests         Apr-22
# 1      Armenia                Peace plan protests         Nov-20
# 2       Brazil    Indigenous land rights protests         Jun-21
# 3       Canada  Coronavirus restrictions protests         Apr-20
# 4         Iran   Public sector employees protests         Jan-22
# ..         ...                                ...            ...
# 324      Yemen             Salary payment protest         Mar-21
# 325      Yemen            Cost of living protests         Sep-18
# 326   Zimbabwe                 Fuel price protest         Jan-19
# 327   Zimbabwe                  Electoral protest         Aug-18
# 328   Zimbabwe                     Mugabe protest         Nov-17
#
#     Özgürlük Derecesi (Durum)  \
# 0                        Free
# 1                 Partly free
# 2                        Free
# 3                        Free
# ...

# %% [markdown]
# > # Ülkeler ve Depremler
#
# ![Depremler](https://i.hizliresim.com/g1epfoq.png)

# %%
df6 = pd.read_csv('Worldwide-Earthquake-database-.csv')

df6
# Out:
#          ID Tsunami   Yıl   Ay   Gün  Saat  Dakika  Saniye  Odak Derinliği  \
# 0         1      No -2150  NaN   NaN   NaN     NaN     NaN             NaN
# 1         2     Yes -2000  NaN   NaN   NaN     NaN     NaN             NaN
# 2         3      No -2000  NaN   NaN   NaN     NaN     NaN            18.0
# 3      5877     Yes -1610  NaN   NaN   NaN     NaN     NaN             NaN
# 4         8      No -1566  NaN   NaN   NaN     NaN     NaN             NaN
# ...     ...     ...   ...  ...   ...   ...     ...     ...             ...
# 6188  10488      No  2020  4.0   1.0  12.0    23.0    27.0            10.0
# 6189  10490     Yes  2020  5.0   2.0  12.0    51.0     6.0            17.0
# 6190  10491      No  2020  5.0   7.0  20.0    18.0    22.0            10.0
# 6191  10494      No  2020  5.0  18.0  13.0    48.0     3.0            10.0
# 6192  10501     Yes  2020  5.0  29.0   5.0    30.0     NaN             NaN
#
#       EQ_PRIMARY  ...  Toplam Kayıp  Toplam Kayıp Açıklaması  \
# ...

# %% [markdown]
# > # Ülkeler ve İntihar Oranları
#
# ![İntiharlar](https://i.hizliresim.com/qppprkd.jpg)

# %%
df7 = pd.read_csv('suicide_dataset--.csv')

df7
# Out:
#                                     Ülke    Cinsiyet   Yıl  İntihar Oranı  \
# 0                            Afghanistan  Both sexes  2000            8.1
# 1                            Afghanistan        Male  2000           14.3
# 2                            Afghanistan      Female  2000            1.7
# 3                                Albania  Both sexes  2000            5.8
# 4                                Albania        Male  2000            8.2
# ...                                  ...         ...   ...            ...
# 2712  Venezuela (Bolivarian Republic of)         NaN  2017            NaN
# 2713                            Viet Nam         NaN  2017            NaN
# 2714                               Yemen         NaN  2017            NaN
# 2715                              Zambia         NaN  2017            NaN
# 2716                            Zimbabwe         NaN  2017            NaN
#
#      Akıl hastaneleri (100.000 nüfus başına)  \
# ...
